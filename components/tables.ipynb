# %% [markdown]
# # 📋 Porównanie tabel – Vuetify, PrimeVue i Quasar
#
# W tej sekcji porównujemy implementacje **tabel**. Najpierw pokazę, jak zaimplementować zwykłą tabele korzystając z czytego vue:
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#  <table border="1" cellpadding="6">
#     <thead>
#       <tr>
#         <th>Imię</th>
#         <th>Wiek</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr v-for="u in users" :key="u.id">
#         <td>{{ u.name }}</td>
#         <td>{{ u.age }}</td>
#       </tr>
#     </tbody>
#   </table>
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/ClearVue/BasicTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
# <br>
# Jak widać to bardzo proste! vue udstępnia takie tagi jak table, thead - nazyw kolumn, tbody - zawartość tabeli (wierszy), tr - wiersz, td - komórka w wierszu, th - koórka w wierszu zerowym tabeli (nagłówku).
#
# Teraz zaprezentuje jak taka basic tabela wyglada po uyciu bibliotek komponentów **Vuetify**, **PrimeVue** i **Quasar**. 2b2727ff
#
#
# **Vuetify**,
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#  <v-data-table :items="users" :headers="headers"></v-data-table>
#   <!--script-->
#   const users = [
#   { id: 1, name: 'Jan', age: 30 },
#   { id: 2, name: 'Ola', age: 25 },
#   { id: 3, name: 'Piotr', age: 40 }
#   ]
#   const headers = [
#     { title: 'First Name', value: 'name' },
#     { title: 'Age', key: 'age' },
#   ]
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/Vuetify/BasicTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# **PrimeVue**
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#  <DataTable :value="users">
#     <Column field="name" header="Imię" />
#     <Column field="age" header="Wiek" />
#   </DataTable>
#
#   <!--script-->
#   const users = [
#   { id: 1, name: 'Jan', age: 30 },
#   { id: 2, name: 'Ola', age: 25 },
#   { id: 3, name: 'Piotr', age: 40 }
# ]
#
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/PrimeVue/BasicTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# **Quasar**
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#  <q-table
#         :rows="users"
#         :columns="basicColumns"
#         row-key="id"
#         flat
#         bordered
#         dense
#   />
#   <!--script-->
#   const users = [
#   { id: 1, name: 'Jan', age: 30 },
#   { id: 2, name: 'Ola', age: 25 },
#   { id: 3, name: 'Piotr', age: 40 }
# ]
# const basicColumns = [
#   { name: 'name', label: 'Imię', field: 'name' },
#   { name: 'age', label: 'Wiek', field: 'age' }
# ]
#
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/Quasar/BasicTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# Patrząc na powysze kody, mozemy stwierdzić, e na pewno są proste do zrozumienia. Mi się osobiście podoba w komponentach z PrimeVue, ze dodjąc je w tagach od razu widać jaki komponent to jest - tutaj wielkimi literami świeci nam się **DataTable**. Pozostałe dwie biblioteki mają tago zblione do zwykłego vue stylem ich aplikowania, jednak szczerze mówiąc do mnie nie przemawiają, bo są takie nie rzucające się w oczy. Rónica w kodzie jest te taka, ze biblioteka PrimeVue nie potrzebuje oddzielnej zmiennej mówiącej jakie kolumny ma mieć tabela, tu po prostu się podaje Column = coś od razu w templecie - jest to kolejna rzecz moim zdaniem na plus. Minusem dla PrimeVue jest to, ze przy renderowaniu nie wyświetla nam się liczba wierszy oraz moliwość wyboru tego tak jak w pozostałych dwóch bibliotekach. Jednak co warto jeszcze zauwazyć na plus PrimeVue - tabela ma ograniczony defaultowo rozmiar a nie jest rozlana wszerz na całą stronę jak w pozostałych dwóch.
#
# Jednak warto dodać, ze w PrimeVue mozemy takze otrzymać widok ilości wierszy oraz wybór wyświetlanej liczby wierszy na stronę, dodając tylko do taga <DataTable ...> to:
#  ```vue
#       :paginator="true" //włącza stronicowanie.
#       :rows="5" //domyślnie pokazuje 5 wierszy na stronę.
#       :rowsPerPageOptions="[5, 10, 20]" //dropdown, który pozwala użytkownikowi zmienić liczbę wierszy na stronie.
#       :showCurrentPageReport="true" //pokazuje raport: "Showing 1 to 5 of 7 entries"
# ```
#
# Po zapoznaniu się z podstawowymi podejściami stosowania komponentu tablicy w poszczególnych bibliotekach zobaczmy jak to wygląda dla bardziej zaawansowanych tablic.
#
# ---
# ## Expanded Table
#
# Uwaga! dla Vuetify komponent ExpandedTable nie istnieje. Stworzyłam go tak na prawdę uzywając zwykłego vue + komponenty takie jak ładne przyciski z Vuetify.
#
# **Vuetify**,
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# **Brak komponentu**
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/Vuetify/ExpandedTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# **PrimeVue**
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#  <DataTable
#     :value="wydzialyData"
#     dataKey="id"
#     v-model:expandedRows="expandedRows"
#     tableStyle="min-width: 30rem"
#   >
#     <Column expander style="width: 3rem" />
#     <Column field="nazwa" header="Wydział" />
#
#     <template #expansion="slotProps">
#       <ul class="ml-4 list-disc">
#         <li v-for="k in slotProps.data.kierunki" :key="k.id">
#           {{ k.nazwa }}
#         </li>
#       </ul>
#     </template>
#   </DataTable>
#
#
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/PrimeVue/ExpandedTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# **Quasar**
# <div style="display: flex; gap: 10px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#   <q-table
#         :rows="wydzialyData"
#         :columns="expandedColumns"
#         row-key="id"
#         v-model:expanded="expanded"
#         flat
#         bordered
#         dense
#       >
#         <template v-slot:body="props">
#           <q-tr :props="props">
#             <q-td auto-width>
#               <q-btn
#                 flat
#                 dense
#                 round
#                 :icon="expanded.includes(props.row.id)
#                 ? 'expand_less' : 'expand_more'"
#                 @click="toggleRow(props.row.id)"
#               />
#             </q-td>
#             <q-td v-for="col in expandedColumns.slice(1)"
#             :key="col.name">
#               {{ props.row[col.field] }}
#             </q-td>
#           </q-tr>
#
#           <q-tr v-if="expanded.includes(props.row.id)">
#             <q-td colspan="2">
#               <ul class="q-ml-md">
#                 <li v-for="k in props.row.kierunki"
#                 :key="k.id">{{ k.nazwa }}</li>
#               </ul>
#             </q-td>
#           </q-tr>
#         </template>
#   </q-table>
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/Quasar/ExpandedTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
#
# Dalej dla mnie tutaj prostotą góruje PrimeVue!
#
# ---
#
# ## Filtered Tables
#   <!-- Lewa kolumna: kod -->
# **Tu nawet nie wklejam kodu, bo jest tak długi, ze nie ma sensu**
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/Vuetify/FilteredTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# **PrimeVue**
# <div style="display: flex; gap: 20px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#  <InputText v-model="search" placeholder="Search by name..." />
#     <Dropdown
#       v-model="selectedWydzial"
#       :options="wydzialyFilterOptions"
#       optionLabel="nazwa"
#       optionValue="id"
#       placeholder="Wybierz wydział"
#       showClear
#     />
#   </div>
#
#   <DataTable :value="filteredStudents" tableStyle="min-width: 30rem">
#     <Column field="name" header="Name" />
#     <Column field="wydzial" header="Wydział" />
#     <Column field="kierunek" header="Kierunek" />
#     <template #empty>Brak wyników</template>
#   </DataTable>
#
#
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/PrimeVue/FilteredTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# **Quasar**
# <div style="display: flex; gap: 10px;">
#
#   <!-- Lewa kolumna: kod -->
# ```vue
#
#
#       <div class="q-gutter-sm row items-center">
#         <q-input filled v-model="search" label="Search by name..." dense />
#         <q-select
#           filled
#           v-model="selectedWydzial"
#           :options="wydzialyFilterOptions"
#           option-label="nazwa"
#           option-value="id"
#           label="Select Wydział"
#           clearable
#           dense
#           emit-value
#           map-options
#         />
#       </div>
#
#       <q-table
#         :rows="filteredStudents"
#         :columns="studentColumns"
#         row-key="id"
#         flat
#         bordered
#         dense
#         no-data-label="Brak wyników"
#       />
#
# ```
#
#   <!-- Prawa kolumna: podgląd -->
#   <div style="flex: 1; display: flex; justify-content: center; align-items: center;">
#     <img src="../images/Quasar/FilteredTable.png" alt="Mój wykres" style="max-width: 100%; height: auto; border: 1px solid #ccc; border-radius: 2px;">
#   </div>
# </div>
#
# ## 🏗 Przykłady kodu i wizualizacji
#
# | Vuetify | PrimeVue | Quasar |
# |---------|----------|--------|
# | **Kod:** | **Kod:** | **Kod:** |
#
# | **Wizualizacja:** | **Wizualizacja:** | **Wizualizacja:** |
# | ![Vuetify Table](./images/vuetify-table.png) | ![PrimeVue Table](./images/primevue-table.png) | ![Quasar Table](./images/quasar-table.png) |
# | **Uwagi:** | **Uwagi:** | **Uwagi:** |
# | Łatwe sortowanie, filtr, Material Design | Szeroki wybór konfiguracji kolumn, wsparcie eksportu | Wszystko w jednym frameworku, integracja z mobilnymi i desktopowymi appkami |
#
# ---
#
# ## 🏁 Podsumowanie
#
# - **Vuetify** – najlepsze dla projektów zgodnych z Material Design, prosty sort/filter.
# - **PrimeVue** – elastyczne tabele z wieloma funkcjami, np. eksport CSV, paginacja.
# - **Quasar** – idealne jeśli używasz frameworka do całej aplikacji, dobrze działa z PWA i mobile.
#
# ---
#
# [⬅ Powrót do strony głównej](../README.md)
