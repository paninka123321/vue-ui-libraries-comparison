# %% [markdown]
# # 📘 Home Page – Porównanie podejść w Vue.js, Nuxt.js i bibliotekach komponentów
#
# Ten plik pełni rolę **strony głównej dokumentacji**.
# Opisuje, co znajdzie się w projekcie i jak zorganizowana jest treść.
#
# **Uwagi:** W zamyśle ten projekt miał te brać pod uwagę bibliotekę NuxtUI oraz Nuxt.js, jednak okazało się niemoliwością zaintsalowanie poprawie Nuxt.js na moim komputerze (pomimo wielu rozmów z chatem, przeglądania problemów na stackoverflow i reddicie. Podobny przypadek jak u mnie był 3 lata temu na Reddicie i tam udało się go rozwiązać podanym przez komentujących kodem u mnie nie.) Bez Nuxt.js NUxtUI działa bardzo średnio, cięzko było cokolwiek z nim zrobić, więc się poddałam i poświęciłam innym bibliotekom. Poniej mała notka czego mona się spodziewać po bibliotece NuxtUI jakby ktoś był ciekawy:
# * dokumentacja wygląda na przestronną i dobrze zbudowaną (podobna struktura do tej z primevue i quasar)
# * na pierwszy rzut oka dostępnych jest wiele komponentów (ale pidoban ilość jak w quasarze czy primevue)
#
# ---
#
# ## 🗂 Zawartość pliku
#
# - **Main** – sekcja główna z porównaniem:
#   - implementacji komponentów w czystym **Vue.js**,
#   - gotowych bibliotek (np. Vuetify, PrimeVue, Element Plus, Quasar).
#
#   W tej części znajdziesz także:
#   - porównanie możliwości **łączenia z Cookiecutterem**,
#   - opis jak wygląda **konteneryzacja (Docker)** dla tych podejść.
#
# - **Komponenty** – rozwijana zakładka zawierająca linki do stron z opisami poszczególnych komponentów:
#   - [Tabele](./components/tables.ipynb)
#   - [Wykresy](./components/charts.md)
#   - [Tab Bary / Nawigacja](./components/tabs.md)
#   - [Logowanie](./components/auth.md)
#
# - **Podsumowanie** – końcowa sekcja z porównaniem i rekomendacjami.
#
# ---
#
# ## 🔖 Zakładki
#
# ### Main
# Tutaj znajdzie się:
# - omówienie implementacji bibliotek komponentów,
# - przykłady kodu,
# - różnice w strukturze projektu,
# - uwagi o integracji z Cookiecutterem i Dockerem.
#
# ### Komponenty
# > Rozwijana lista szczegółowych opisów i przykładów.
# Kliknij w wybrany komponent, aby przejść do osobnego pliku.
#
# - [Tabele](./components/tables.md)
# - [Wykresy](./components/charts.md)
# - [Tab Bary](./components/tabs.md)
# - [Logowanie](./components/auth.md)
#
# ### Podsumowanie
# #### Porównanie bibliotek komponentów Vue: Vuetify vs PrimeVue vs Quasar
#
# | Cecha / Biblioteka             | **Vuetify**                                      | **PrimeVue**                                      | **Quasar**                                         |
# |-------------------------------|--------------------------------------------------|---------------------------------------------------|----------------------------------------------------|
# | **Próg wejścia**        | duzy                         | mały (ładnie widoczne w kodzie jaki komponent dodajemy)         | Duzy ale nadla mniejszy niz vuetify                                      |
# | **Liczba komponentów**        | Ponad 80                                          | Ponad 90                                          | Ponad 70                                           |
# | **Expanded Tables**        | Nie                                        | Tak                                       | Tak                                          |
# | **Filtered Tables**        | Nie                                       | Tak                                        | Nie                                           |
# | **Gotowe okienko chatów**        | nie wiem                                       | Nie                                  | Tak                                       |
# | **Wykresy**        | Nie                                         | Tak, puls dobre wsparcie dla Chart.js                                         | Nie, ale dobrze się łączy z Chart.js 70                                           |
# | **Personalizacja stylów**     | Stylowanie przez SASS i CSS variables             | Łatwe przez CSS i motywy PrimeFlex                | Bardzo elastyczne, pełna kontrola przez zmienne i CSS |
# | **Natywność (szczególnie aplikacje mobilne)**| Nie                                | Nie                                               | Tak (PWA, Android, iOS, Electron)            |
# | **Dokumentacja**              | Moim zdaniem bardzo słaba                     | Przejrzysta i bogata w przykłady                 | Przejrzysta i bogata w przykłady           |
# | **Społeczność i popularność** | nie wiem              | Szybko rosnąca , caly czas aktualizacje na githubie                                  | Caly czas aktualizacje na githubie, jednak brak konkretnych deklaracji od autorów               |
# | **Integracje z innymi narzędziami** | Dobra integracja z Nuxt, Vite, TypeScript        | Działa dobrze z Vite i TypeScript                | Quasar CLI + Vite + TypeScript                    |
#
# #### Dodatkowe uwagi:
# Uywając PrimeVue trzeba uwazać na korzystanie z Card komponent wraz z innymi komponentami, np wykresami, karta moze przyslonic wykres i ona tak na prawde sie renderuje ale my tego nie widzimy bo jest pod kartą.
#
# ### W skrócie
#
# - **Vuetify** – beznadziejny moim xzdaniem
# - **PrimeVue** – świetny wybór, jeśli zależy Ci na dużym wyborze gotowych komponentów i elastycznym stylu.
# - **Quasar** – najlepszy, gdy planujesz aplikację multiplatformową (web, mobilną, desktopową) z jednym kodem źródłowym.
#
#
#
#
#
#
# ---
#
# ✅ Dzięki tej strukturze łatwo będzie rozwijać dokumentację krok po kroku i dopisywać szczegółowe przykłady.

# %% [markdown]
# **NuxtUI, Quazar**, PrimeVue, Vuetify, Nuxt.js,

# %% [markdown]
# czy nuxt ui jest lepiej supportowany niz primevue przez nuxt.js

# %% [markdown]
# czy cookiecutter dziala dla frontendu, fork cookiecutter - django + nuxt + vue?

# %% [markdown]
# prosta aplikacja w django - gdzie dane beda przychodzic z api restowego a nie beda zakodowane we frontendzie, zrobic get i post, baza moze byc w pliku w jsonie (przetestowac komunikacje frontend + backend)
